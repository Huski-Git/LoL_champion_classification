# %%
from selenium import webdriver
from bs4 import BeautifulSoup
import requests
import pandas as pd
import time
from selenium.webdriver.common.action_chains import ActionChains
from tqdm.notebook import tqdm
import pickle
import os
from selenium.webdriver.support.ui import Select

# %%
url='https://leagueoflegends.fandom.com/wiki/List_of_champions'
r=requests.get(url)
soup=BeautifulSoup(r.text,'html.parser')

# %%
#Creating end part of each link for scraping

list_of_champs=[champion.text.replace(',','').split()[:2] for champion in soup.find_all('span',attrs={'data-skin':'Original'})]

two_names=['Aurelion','Dr.','Jarvan','Lee','Master','Miss','Tahm','Xin','Twisted']

#Turning two worded names into 1 string
list_of_champs=[champ[0]+' '+champ[1] if champ[0] in two_names else champ[0] for champ in list_of_champs]

#Choosing only distinct champions & then alphabetizing incase there are any duplicates.
list_of_champs=sorted(list(set(list_of_champs)))
list_of_champs
# Out:
# ['Aatrox',
#  'Ahri',
#  'Akali',
#  'Alistar',
#  'Amumu',
#  'Anivia',
#  'Annie',
#  'Aphelios',
#  'Ashe',
#  'Aurelion Sol',
#  'Azir',
#  'Bard',
#  'Blitzcrank',
#  'Brand',
#  'Braum',
#  'Caitlyn',
#  'Camille',
#  'Cassiopeia',
#  "Cho'Gath",
#  'Corki',
#  'Darius',
#  'Diana',
#  'Dr. Mundo',
#  'Draven',
#  'Ekko',
#  'Elise',
#  'Evelynn',
#  'Ezreal',
#  'Fiddlesticks',
#  'Fiora',
#  'Fizz',
#  'Galio',
#  'Gangplank',
#  'Garen',
#  'Gnar',
#  'Gragas',
#  'Graves',
#  'Hecarim',
#  'Heimerdinger',
#  'Illaoi',
#  'Irelia',
#  'Ivern',
#  'Janna',
#  'Jarvan IV',
#  'Jax',
#  'Jayce',
#  'Jhin',
#  'Jinx',
#  "Kai'Sa",
#  'Kalista',
#  'Karma',
#  'Karthus',
#  'Kassadin',
#  'Katarina',
#  'Kayle',
#  'Kayn',
#  'Kennen',
#  "Kha'Zix",
#  'Kindred',
#  'Kled',
#  "Kog'Maw",
#  'LeBlanc',
#  'Lee Sin',
#  'Leona',
#  'Lissandra',
#  'Lucian',
#  'Lulu',
#  'Lux',
#  'Malphite',
#  'Malzahar',
#  'Maokai',
#  'Master Yi',
#  'Miss Fortune',
#  'Mordekaiser',
#  'Morgana',
#  'Nami',
#  'Nasus',
#  'Nautilus',
#  'Neeko',
#  'Nidalee',
#  'Nocturne',
#  'Nunu',
#  'Olaf',
#  'Orianna',
#  'Ornn',
#  'Pantheon',
#  'Poppy',
#  'Pyke',
#  'Qiyana',
#  'Quinn',
#  'Rakan',
#  'Rammus',
#  "Rek'Sai",
#  'Renekton',
#  'Rengar',
#  'Riven',
#  'Rumble',
#  'Ryze',
#  'Sejuani',
#  'Senna',
#  'Sett',
#  'Shaco',
#  'Shen',
#  'Shyvana',
#  'Singed',
#  'Sion',
#  'Sivir',
#  'Skarner',
#  'Sona',
#  'Soraka',
#  'Swain',
#  'Sylas',
#  'Syndra',
#  'Tahm Kench',
#  'Taliyah',
#  'Talon',
#  'Taric',
#  'Teemo',
#  'Thresh',
#  'Tristana',
#  'Trundle',
#  'Tryndamere',
#  'Twisted Fate',
#  'Twitch',
#  'Udyr',
#  'Urgot',
#  'Varus',
#  'Vayne',
#  'Veigar',
#  "Vel'Koz",
#  'Vi',
#  'Viktor',
#  'Vladimir',
#  'Volibear',
#  'Warwick',
#  'Wukong',
#  'Xayah',
#  'Xerath',
#  'Xin Zhao',
#  'Yasuo',
#  'Yorick',
#  'Yuumi',
#  'Zac',
#  'Zed',
#  'Ziggs',
#  'Zilean',
#  'Zoe',
#  'Zyra']

# %% [markdown]
# # Scraping Champions & Champions Stats

# %%
#Saving the Models
def save_pickle(element,file):
    with open(file, 'wb') as handle:
        pickle.dump(element, handle, protocol=pickle.HIGHEST_PROTOCOL)

#Loading the models
def load_pickle(file):
    with open(file, 'rb') as handle:
        return pickle.load(handle)

# %%
driver = webdriver.Chrome(executable_path='/Users/Huski/Downloads/chromedriver')
driver.get('https://leagueoflegends.fandom.com/wiki/List_of_champions')

cookies_button=driver.find_element_by_class_name('_2o0B8MF50eAK1jv60jldUQ')
cookies_button.click()

# %%
health=[]
health_per_lvl=[]
health_regen=[]
health_regen_per_lvl=[]
ad=[]
ad_per_lvl=[]
armor=[]
armor_per_lvl=[]
mr=[]
mr_per_lvl=[]
attack_speed=[]
ms=[]
atk_range=[]
top3_attrs=[]

all_stats=[health,health_per_lvl,health_regen,health_regen_per_lvl,
           ad,ad_per_lvl,armor,armor_per_lvl,mr,mr_per_lvl,attack_speed,
           ms,atk_range,top3_attrs]

all_stats_name=['health','health_per_lvl','health_regen','health_regener_per_lvl',
                'ad','ad_per_lvl','armor','armor_per_lvl','mr','mr_per_lvl','attack_speed','ms',
                'atk_range','top3_attrs']

lst1=["Cho'Gath","Vel'Koz","Kha'Zix","Kai'Sa",'LeBlanc']
lst2=["Kog'Maw","Rek'Sai"]

try:
    for stat,stat_name in zip(all_stats,all_stats_name):
        stat.extend(load_pickle('{}.pkl'.format(stat_name)))
except:
    pass

for champion in tqdm(list_of_champs[len(health):]):
    
    time.sleep(10)
    
    champion_button = driver.find_element_by_partial_link_text('{}'.format(champion))
    driver.execute_script("arguments[0].scrollIntoView();", champion_button)
    driver.execute_script("window.scrollBy(0, -100)")
    
    champion_button.click()
    
    time.sleep(20)
    
    # Source code is very inconsistent  
    name = champion
    if ' ' in champion:
        name=name.replace(' ','').replace('.','')
    elif champion=='Kled':
        name='Kled1'
    elif champion=='Wukong':
        name='MonkeyKing'
    elif champion in lst1:
        name=name.replace("'",'').capitalize()
    elif champion in lst2:
        name=name.replace("'",'')
    
    
    
    level_button=driver.find_element_by_id('lvl_{}'.format(name))

    driver.execute_script("arguments[0].scrollIntoView();", level_button)
    driver.execute_script("window.scrollBy(0, -100)")

    select= Select(level_button)
    select.select_by_index(0)
    
    soup=BeautifulSoup(driver.page_source,'html.parser')
    
    attributes=[]
    
    for x in soup.find_all('span',attrs={'class':'glossary'})[:3]:
        attributes.append(x.text)
    
    top3_attrs.append(attributes)
    
    
    health.append(soup.find('span',attrs={'id':"Health_{}".format(name)}).text)
    health_per_lvl.append(soup.find('span',attrs={'id':"Health_{}_lvl".format(name)}).text)
    health_regen.append(soup.find('span',attrs={'id':'HealthRegen_{}'.format(name)}).text)
    health_regen_per_lvl.append(soup.find('span',attrs={'id':'HealthRegen_{}_lvl'.format(name)}).text)

    ad.append(soup.find('span',attrs={'id':'AttackDamage_{}'.format(name)}).text)
    ad_per_lvl.append(soup.find('span',attrs={'id':'AttackDamage_{}_lvl'.format(name)}).text)

    armor.append(soup.find('span',attrs={'id':'Armor_{}'.format(name)}).text)
    armor_per_lvl.append(soup.find('span',attrs={'id':'Armor_{}_lvl'.format(name)}).text)

    mr.append(soup.find('span',attrs={'id':'MagicResist_{}'.format(name)}).text)
    mr_per_lvl.append(soup.find('span',attrs={'id':'MagicResist_{}_lvl'.format(name)}).text)

    attack_speed.append(soup.find('div',attrs={'data-source':'attack speed'}).text)

    ms.append(soup.find('span',attrs={'id':'MovementSpeed_{}'.format(name)}).text)

    atk_range.append(soup.find('span',attrs={'id':'AttackRange_{}'.format(name)}).text)
    
    for stat,stat_name in zip(all_stats,all_stats_name):
        save_pickle(stat,'{}.pkl'.format(stat_name))

        
    driver.back()
# Out:
# HBox(children=(IntProgress(value=0, max=13), HTML(value='')))

# %%
health=[]
health_per_lvl=[]
health_regen=[]
health_regen_per_lvl=[]
ad=[]
ad_per_lvl=[]
armor=[]
armor_per_lvl=[]
mr=[]
mr_per_lvl=[]
attack_speed=[]
ms=[]
atk_range=[]
top3_attrs=[]

all_stats=[health,health_per_lvl,health_regen,health_regen_per_lvl,
           ad,ad_per_lvl,armor,armor_per_lvl,mr,mr_per_lvl,attack_speed,
           ms,atk_range,top3_attrs]

all_stats_name=['health','health_per_lvl','health_regen','health_regen_per_lvl',
                'ad','ad_per_lvl','armor','armor_per_lvl','mr','mr_per_lvl','attack_speed','ms',
                'atk_range','top3_attrs']

# %%
for stat,stat_name in zip(all_stats,all_stats_name):
    stat.extend(load_pickle('{}.pkl'.format(stat_name)))

# %%
LoL=pd.DataFrame(all_stats).T
LoL
# Out:
#           0         1    2          3       4          5       6          7  \
# 0       580    (+ 90)    3      (+ 1)      60      (+ 5)      38   (+ 3.25)
# 1       526    (+ 92)  6.5    (+ 0.6)   53.04      (+ 3)   20.88    (+ 3.5)
# 2       575    (+ 95)    8    (+ 0.5)    62.4    (+ 3.3)      23    (+ 3.5)
# 3       600   (+ 106)  8.5   (+ 0.85)      62   (+ 3.75)      44    (+ 3.5)
# 4    613.12    (+ 84)    9   (+ 0.85)   53.38    (+ 3.8)      33    (+ 3.8)
# ..      ...       ...  ...        ...     ...        ...     ...        ...
# 143     584    (+ 85)    7   (+ 0.65)      63    (+ 3.4)      32    (+ 3.5)
# 144     536    (+ 92)  6.5    (+ 0.6)  54.208    (+ 3.1)  21.544    (+ 3.3)
# 145     504    (+ 82)  5.5    (+ 0.5)   51.64      (+ 3)      24    (+ 3.8)
# 146     560    (+ 92)  6.5    (+ 0.6)      58    (+ 3.3)    20.8    (+ 3.5)
# 147     504    (+ 79)  5.5    (+ 0.5)  53.376    (+ 3.2)      29      (+ 3)
#
#         8          9            10   11   12                                13
# 0    32.1   (+ 1.25)  Base AS0.651  345  175  [ Juggernaut,  Manaless,  Melee]
# 1      30    (+ 0.5)  Base AS0.668  330  550          [ Burst,  Mana,  Ranged]
# 2      37   (+ 1.25)  Base AS0.625  345  125      [ Assassin,  Energy,  Melee]
# 3    32.1   (+ 1.25)  Base AS0.625  330  125        [ Vanguard,  Mana,  Melee]
# 4    32.1   (+ 1.25)  Base AS0.736  335  125        [ Vanguard,  Mana,  Melee]
# ..    ...        ...           ...  ...  ...                               ...
# 143  32.1   (+ 1.25)  Base AS0.651  345  125      [ Assassin,  Energy,  Melee]
# 144    30    (+ 0.5)  Base AS0.656  325  550      [ Artillery,  Mana,  Ranged]
# 145    30    (+ 0.5)  Base AS0.625  335  550     [ Specialist,  Mana,  Ranged]
# 146    30    (+ 0.5)  Base AS0.625  340  550          [ Burst,  Mana,  Ranged]
# 147    30    (+ 0.5)  Base AS0.625  340  575        [ Catcher,  Mana,  Ranged]
#
# [148 rows x 14 columns]

# %%
for x,y in enumerate(all_stats_name):
    print(x,y)
# Out:
# 0 health
# 1 health_per_lvl
# 2 health_regen
# 3 health_regen_per_lvl
# 4 ad
# 5 ad_per_lvl
# 6 armor
# 7 armor_per_lvl
# 8 mr
# 9 mr_per_lvl
# 10 attack_speed
# 11 ms
# 12 atk_range
# 13 top3_attrs

# %%
LoL.rename(columns=dict(enumerate(all_stats_name)),index=dict(enumerate(list_of_champs)),inplace=True)

# %%
LoL
# Out:
#          health health_per_lvl health_regen health_regen_per_lvl      ad  \
# Aatrox      580         (+ 90)            3                (+ 1)      60
# Ahri        526         (+ 92)          6.5              (+ 0.6)   53.04
# Akali       575         (+ 95)            8              (+ 0.5)    62.4
# Alistar     600        (+ 106)          8.5             (+ 0.85)      62
# Amumu    613.12         (+ 84)            9             (+ 0.85)   53.38
# ...         ...            ...          ...                  ...     ...
# Zed         584         (+ 85)            7             (+ 0.65)      63
# Ziggs       536         (+ 92)          6.5              (+ 0.6)  54.208
# Zilean      504         (+ 82)          5.5              (+ 0.5)   51.64
# Zoe         560         (+ 92)          6.5              (+ 0.6)      58
# Zyra        504         (+ 79)          5.5              (+ 0.5)  53.376
#
#         ad_per_lvl   armor armor_per_lvl    mr mr_per_lvl  attack_speed   ms  \
# Aatrox       (+ 5)      38      (+ 3.25)  32.1   (+ 1.25)  Base AS0.651  345
# Ahri         (+ 3)   20.88       (+ 3.5)    30    (+ 0.5)  Base AS0.668  330
# Akali      (+ 3.3)      23       (+ 3.5)    37   (+ 1.25)  Base AS0.625  345
# Alistar   (+ 3.75)      44       (+ 3.5)  32.1   (+ 1.25)  Base AS0.625  330
# Amumu      (+ 3.8)      33       (+ 3.8)  32.1   (+ 1.25)  Base AS0.736  335
# ...            ...     ...           ...   ...        ...           ...  ...
# Zed        (+ 3.4)      32       (+ 3.5)  32.1   (+ 1.25)  Base AS0.651  345
# Ziggs      (+ 3.1)  21.544       (+ 3.3)    30    (+ 0.5)  Base AS0.656  325
# Zilean       (+ 3)      24       (+ 3.8)    30    (+ 0.5)  Base AS0.625  335
# Zoe        (+ 3.3)    20.8       (+ 3.5)    30    (+ 0.5)  Base AS0.625  340
# Zyra       (+ 3.2)      29         (+ 3)    30    (+ 0.5)  Base AS0.625  340
#
#         atk_range                        top3_attrs
# Aatrox        175  [ Juggernaut,  Manaless,  Melee]
# Ahri          550          [ Burst,  Mana,  Ranged]
# Akali         125      [ Assassin,  Energy,  Melee]
# Alistar       125        [ Vanguard,  Mana,  Melee]
# Amumu         125        [ Vanguard,  Mana,  Melee]
# ...           ...                               ...
# Zed           125      [ Assassin,  Energy,  Melee]
# Ziggs         550      [ Artillery,  Mana,  Ranged]
# Zilean        550     [ Specialist,  Mana,  Ranged]
# Zoe           550          [ Burst,  Mana,  Ranged]
# Zyra          575        [ Catcher,  Mana,  Ranged]
#
# [148 rows x 14 columns]

# %%
LoL['attack_speed']=LoL['attack_speed'].apply(lambda x: x.replace('Base AS',''))

# %%
for column in LoL.columns:
    if 'lvl' in column:
        LoL[column]=LoL[column].apply(lambda x: x.strip().replace('(','').replace(')','').replace('+',''))

# %%
LoL['Primary_attrs']=LoL['top3_attrs'].apply(lambda x: x[0])
LoL['Second_attrs']=LoL['top3_attrs'].apply(lambda x: x[1])
LoL['Third_attrs']=LoL['top3_attrs'].apply(lambda x: x[2])
LoL.drop('top3_attrs',axis=1,inplace=True)

# %%
LoL.loc[:,:'atk_range']
# Out:
#          health health_per_lvl health_regen health_regen_per_lvl      ad  \
# Aatrox      580             90            3                    1      60
# Ahri        526             92          6.5                  0.6   53.04
# Akali       575             95            8                  0.5    62.4
# Alistar     600            106          8.5                 0.85      62
# Amumu    613.12             84            9                 0.85   53.38
# ...         ...            ...          ...                  ...     ...
# Zed         584             85            7                 0.65      63
# Ziggs       536             92          6.5                  0.6  54.208
# Zilean      504             82          5.5                  0.5   51.64
# Zoe         560             92          6.5                  0.6      58
# Zyra        504             79          5.5                  0.5  53.376
#
#         ad_per_lvl   armor armor_per_lvl    mr mr_per_lvl attack_speed   ms  \
# Aatrox           5      38          3.25  32.1       1.25        0.651  345
# Ahri             3   20.88           3.5    30        0.5        0.668  330
# Akali          3.3      23           3.5    37       1.25        0.625  345
# Alistar       3.75      44           3.5  32.1       1.25        0.625  330
# Amumu          3.8      33           3.8  32.1       1.25        0.736  335
# ...            ...     ...           ...   ...        ...          ...  ...
# Zed            3.4      32           3.5  32.1       1.25        0.651  345
# Ziggs          3.1  21.544           3.3    30        0.5        0.656  325
# Zilean           3      24           3.8    30        0.5        0.625  335
# Zoe            3.3    20.8           3.5    30        0.5        0.625  340
# Zyra           3.2      29             3    30        0.5        0.625  340
#
#         atk_range
# Aatrox        175
# Ahri          550
# Akali         125
# Alistar       125
# Amumu         125
# ...           ...
# Zed           125
# Ziggs         550
# Zilean        550
# Zoe           550
# Zyra          575
#
# [148 rows x 13 columns]

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-111-fdba9b461628> in <module>
# ----> 1 eval('hello')
#
# <string> in <module>
#
# NameError: name 'hello' is not defined
