# %%
from selenium import webdriver
from bs4 import BeautifulSoup
import requests
import pandas as pd
import time
from selenium.webdriver.common.action_chains import ActionChains
from tqdm.notebook import tqdm
import pickle
import os
from selenium.webdriver.support.ui import Select
import seaborn as sns
import matplotlib.pyplot as plt

from sklearn.preprocessing import StandardScaler

# %%
url='https://leagueoflegends.fandom.com/wiki/List_of_champions'
r=requests.get(url)
soup=BeautifulSoup(r.text,'html.parser')

# %%
#Creating end part of each link for scraping

list_of_champs=[champion.text.replace(',','').split()[:2] for champion in soup.find_all('span',attrs={'data-skin':'Original'})]

two_names=['Aurelion','Dr.','Jarvan','Lee','Master','Miss','Tahm','Xin','Twisted']

#Turning two worded names into 1 string
list_of_champs=[champ[0]+' '+champ[1] if champ[0] in two_names else champ[0] for champ in list_of_champs]

#Choosing only distinct champions & then alphabetizing incase there are any duplicates.
list_of_champs=sorted(list(set(list_of_champs)))
list_of_champs
# Out:
# ['Aatrox',
#  'Ahri',
#  'Akali',
#  'Alistar',
#  'Amumu',
#  'Anivia',
#  'Annie',
#  'Aphelios',
#  'Ashe',
#  'Aurelion Sol',
#  'Azir',
#  'Bard',
#  'Blitzcrank',
#  'Brand',
#  'Braum',
#  'Caitlyn',
#  'Camille',
#  'Cassiopeia',
#  "Cho'Gath",
#  'Corki',
#  'Darius',
#  'Diana',
#  'Dr. Mundo',
#  'Draven',
#  'Ekko',
#  'Elise',
#  'Evelynn',
#  'Ezreal',
#  'Fiddlesticks',
#  'Fiora',
#  'Fizz',
#  'Galio',
#  'Gangplank',
#  'Garen',
#  'Gnar',
#  'Gragas',
#  'Graves',
#  'Hecarim',
#  'Heimerdinger',
#  'Illaoi',
#  'Irelia',
#  'Ivern',
#  'Janna',
#  'Jarvan IV',
#  'Jax',
#  'Jayce',
#  'Jhin',
#  'Jinx',
#  "Kai'Sa",
#  'Kalista',
#  'Karma',
#  'Karthus',
#  'Kassadin',
#  'Katarina',
#  'Kayle',
#  'Kayn',
#  'Kennen',
#  "Kha'Zix",
#  'Kindred',
#  'Kled',
#  "Kog'Maw",
#  'LeBlanc',
#  'Lee Sin',
#  'Leona',
#  'Lissandra',
#  'Lucian',
#  'Lulu',
#  'Lux',
#  'Malphite',
#  'Malzahar',
#  'Maokai',
#  'Master Yi',
#  'Miss Fortune',
#  'Mordekaiser',
# ...

# %% [markdown]
# # Scraping Champions & Champions Stats

# %%
#Saving the Models
def save_pickle(element,file):
    with open(file, 'wb') as handle:
        pickle.dump(element, handle, protocol=pickle.HIGHEST_PROTOCOL)

#Loading the models
def load_pickle(file):
    with open(file, 'rb') as handle:
        return pickle.load(handle)

# %%
driver = webdriver.Chrome(executable_path='/Users/Huski/Downloads/chromedriver')
driver.get('https://leagueoflegends.fandom.com/wiki/List_of_champions')

cookies_button=driver.find_element_by_class_name('_2o0B8MF50eAK1jv60jldUQ')
cookies_button.click()

# %%
health=[]
health_per_lvl=[]
health_regen=[]
health_regen_per_lvl=[]
ad=[]
ad_per_lvl=[]
armor=[]
armor_per_lvl=[]
mr=[]
mr_per_lvl=[]
attack_speed=[]
ms=[]
atk_range=[]
top3_attrs=[]

all_stats=[health,health_per_lvl,health_regen,health_regen_per_lvl,
           ad,ad_per_lvl,armor,armor_per_lvl,mr,mr_per_lvl,attack_speed,
           ms,atk_range,top3_attrs]

all_stats_name=['health','health_per_lvl','health_regen','health_regener_per_lvl',
                'ad','ad_per_lvl','armor','armor_per_lvl','mr','mr_per_lvl','attack_speed','ms',
                'atk_range','top3_attrs']

lst1=["Cho'Gath","Vel'Koz","Kha'Zix","Kai'Sa",'LeBlanc']
lst2=["Kog'Maw","Rek'Sai"]

try:
    for stat,stat_name in zip(all_stats,all_stats_name):
        stat.extend(load_pickle('{}.pkl'.format(stat_name)))
except:
    pass

for champion in tqdm(list_of_champs[len(health):]):
    
    time.sleep(10)
    
    champion_button = driver.find_element_by_partial_link_text('{}'.format(champion))
    driver.execute_script("arguments[0].scrollIntoView();", champion_button)
    driver.execute_script("window.scrollBy(0, -100)")
    
    champion_button.click()
    
    time.sleep(20)
    
    # Source code is very inconsistent  
    name = champion
    if ' ' in champion:
        name=name.replace(' ','').replace('.','')
    elif champion=='Kled':
        name='Kled1'
    elif champion=='Wukong':
        name='MonkeyKing'
    elif champion in lst1:
        name=name.replace("'",'').capitalize()
    elif champion in lst2:
        name=name.replace("'",'')
    
    
    
    level_button=driver.find_element_by_id('lvl_{}'.format(name))

    driver.execute_script("arguments[0].scrollIntoView();", level_button)
    driver.execute_script("window.scrollBy(0, -100)")

    select= Select(level_button)
    select.select_by_index(0)
    
    soup=BeautifulSoup(driver.page_source,'html.parser')
    
    attributes=[]
    
    for x in soup.find_all('span',attrs={'class':'glossary'})[:3]:
        attributes.append(x.text)
    
    top3_attrs.append(attributes)
    
    
    health.append(soup.find('span',attrs={'id':"Health_{}".format(name)}).text)
    health_per_lvl.append(soup.find('span',attrs={'id':"Health_{}_lvl".format(name)}).text)
    health_regen.append(soup.find('span',attrs={'id':'HealthRegen_{}'.format(name)}).text)
    health_regen_per_lvl.append(soup.find('span',attrs={'id':'HealthRegen_{}_lvl'.format(name)}).text)

    ad.append(soup.find('span',attrs={'id':'AttackDamage_{}'.format(name)}).text)
    ad_per_lvl.append(soup.find('span',attrs={'id':'AttackDamage_{}_lvl'.format(name)}).text)

    armor.append(soup.find('span',attrs={'id':'Armor_{}'.format(name)}).text)
    armor_per_lvl.append(soup.find('span',attrs={'id':'Armor_{}_lvl'.format(name)}).text)

    mr.append(soup.find('span',attrs={'id':'MagicResist_{}'.format(name)}).text)
    mr_per_lvl.append(soup.find('span',attrs={'id':'MagicResist_{}_lvl'.format(name)}).text)

    attack_speed.append(soup.find('div',attrs={'data-source':'attack speed'}).text)

    ms.append(soup.find('span',attrs={'id':'MovementSpeed_{}'.format(name)}).text)

    atk_range.append(soup.find('span',attrs={'id':'AttackRange_{}'.format(name)}).text)
    
    for stat,stat_name in zip(all_stats,all_stats_name):
        save_pickle(stat,'{}.pkl'.format(stat_name))

        
    driver.back()

# %%
health=[]
health_per_lvl=[]
health_regen=[]
health_regen_per_lvl=[]
ad=[]
ad_per_lvl=[]
armor=[]
armor_per_lvl=[]
mr=[]
mr_per_lvl=[]
attack_speed=[]
ms=[]
atk_range=[]
top3_attrs=[]

all_stats=[health,health_per_lvl,health_regen,health_regen_per_lvl,
           ad,ad_per_lvl,armor,armor_per_lvl,mr,mr_per_lvl,attack_speed,
           ms,atk_range,top3_attrs]

all_stats_name=['health','health_per_lvl','health_regen','health_regen_per_lvl',
                'ad','ad_per_lvl','armor','armor_per_lvl','mr','mr_per_lvl','attack_speed','ms',
                'atk_range','top3_attrs']

# %%
for stat,stat_name in zip(all_stats,all_stats_name):
    stat.extend(load_pickle('{}.pkl'.format(stat_name)))

# %%
for champ in top3_attrs:
    for i,attrs in enumerate(champ):
        champ[i]=attrs.replace('\xa0','')

# %%
LoL=pd.DataFrame(all_stats).T

# %%
LoL.rename(columns=dict(enumerate(all_stats_name)),inplace=True)
LoL['attack_speed']=LoL['attack_speed'].apply(lambda x: x.replace('Base AS','').replace('(+ 3%)','').strip())

# %%
for column in LoL.columns:
    if 'lvl' in column:
        LoL[column]=LoL[column].apply(lambda x: x.replace('','0') if x=='' else x.replace('(','').replace(')','').replace('+','').strip())

# %%
LoL
# Out:
#      health health_per_lvl health_regen health_regen_per_lvl      ad  \
# 0       580             90            3                    1      60
# 1       526             92          6.5                  0.6   53.04
# 2       575             95            8                  0.5    62.4
# 3       600            106          8.5                 0.85      62
# 4    613.12             84            9                 0.85   53.38
# ..      ...            ...          ...                  ...     ...
# 143     584             85            7                 0.65      63
# 144     536             92          6.5                  0.6  54.208
# 145     504             82          5.5                  0.5   51.64
# 146     560             92          6.5                  0.6      58
# 147     504             79          5.5                  0.5  53.376
#
#     ad_per_lvl   armor armor_per_lvl    mr mr_per_lvl attack_speed   ms  \
# ...

# %%
LoL['primary_attrs']=LoL['top3_attrs'].apply(lambda x: x[0])
LoL['second_attrs']=LoL['top3_attrs'].apply(lambda x: x[1])
LoL['third_attrs']=LoL['top3_attrs'].apply(lambda x: x[2])
LoL.drop('top3_attrs',axis=1,inplace=True)

# %%
convert_dict={'health':float,
              'health_per_lvl':float,
              'health_regen':float,
              'health_regen_per_lvl':float,
              'ad':float,
              'ad_per_lvl':float,
              'armor':float,
              'armor_per_lvl':float,
              'mr':float,
              'mr_per_lvl':float,
              'attack_speed':float,
              'ms':float,
              'atk_range':float,
              'primary_attrs':str,
              'second_attrs':str,
              'third_attrs':str
             }

# %%
LoL=LoL.astype(convert_dict)
LoL
# Out:
#      health  health_per_lvl  health_regen  health_regen_per_lvl      ad  \
# 0    580.00            90.0           3.0                  1.00  60.000
# 1    526.00            92.0           6.5                  0.60  53.040
# 2    575.00            95.0           8.0                  0.50  62.400
# 3    600.00           106.0           8.5                  0.85  62.000
# 4    613.12            84.0           9.0                  0.85  53.380
# ..      ...             ...           ...                   ...     ...
# 143  584.00            85.0           7.0                  0.65  63.000
# 144  536.00            92.0           6.5                  0.60  54.208
# 145  504.00            82.0           5.5                  0.50  51.640
# 146  560.00            92.0           6.5                  0.60  58.000
# 147  504.00            79.0           5.5                  0.50  53.376
#
#      ad_per_lvl   armor  armor_per_lvl    mr  mr_per_lvl  attack_speed     ms  \
# ...

# %% [markdown]
# # EDA

# %%
LoL.head()
# Out:
#    health  health_per_lvl  health_regen  health_regen_per_lvl     ad  \
# 0  580.00            90.0           3.0                  1.00  60.00
# 1  526.00            92.0           6.5                  0.60  53.04
# 2  575.00            95.0           8.0                  0.50  62.40
# 3  600.00           106.0           8.5                  0.85  62.00
# 4  613.12            84.0           9.0                  0.85  53.38
#
#    ad_per_lvl  armor  armor_per_lvl    mr  mr_per_lvl  attack_speed     ms  \
# 0        5.00  38.00           3.25  32.1        1.25         0.651  345.0
# 1        3.00  20.88           3.50  30.0        0.50         0.668  330.0
# 2        3.30  23.00           3.50  37.0        1.25         0.625  345.0
# 3        3.75  44.00           3.50  32.1        1.25         0.625  330.0
# 4        3.80  33.00           3.80  32.1        1.25         0.736  335.0
#
#    atk_range primary_attrs second_attrs third_attrs
# ...

# %%
LoL.columns
# Out:
# Index(['health', 'health_per_lvl', 'health_regen', 'health_regen_per_lvl',
#        'ad', 'ad_per_lvl', 'armor', 'armor_per_lvl', 'mr', 'mr_per_lvl',
#        'attack_speed', 'ms', 'atk_range', 'primary_attrs', 'second_attrs',
#        'third_attrs'],
#       dtype='object')

# %%
numerical_types='float64'
fixed_num = LoL.select_dtypes(include=numerical_types)

# %%
scaler=StandardScaler()
fixed_num = pd.DataFrame(scaler.fit_transform(fixed_num),columns=fixed_num.columns,index=list_of_champs)

# %%
fig=plt.figure(figsize=(15,10))
ax=fig.gca()
sns.boxplot(data=fixed_num,orient='h',ax=ax,fliersize=5)
plt.show()

# %%
plt.figure(figsize=(20,12))
sns.heatmap(LoL.corr(),annot=True)
plt.show()

# %%
sns.pairplot(LoL,hue='primary_attrs')
# Out:
# /Users/Huski/opt/anaconda3/lib/python3.7/site-packages/statsmodels/nonparametric/kde.py:487: RuntimeWarning: invalid value encountered in true_divide
#   binned = fast_linbin(X, a, b, gridsize) / (delta * nobs)
# /Users/Huski/opt/anaconda3/lib/python3.7/site-packages/statsmodels/nonparametric/kdetools.py:34: RuntimeWarning: invalid value encountered in double_scalars
#   FAC1 = 2*(np.pi*bw/RANGE)**2

# %%
LoL.groupby('primary_attrs').describe()
# Out:
#               health                                                        \
#                count        mean        std    min     25%     50%     75%
# primary_attrs
# Artillery        4.0  535.500000  17.616280  520.0  524.50  531.00  542.00
# Assassin        15.0  584.386667   9.827793  570.0  575.50  585.00  589.00
# Battlemage      11.0  543.498182  31.299234  480.0  529.00  537.00  572.74
# Burst           14.0  527.762857  17.149647  490.0  523.25  527.00  534.00
# Catcher          7.0  558.160000  28.499506  504.0  550.00  560.52  578.80
# Diver           16.0  582.695000  45.639316  534.0  570.00  575.30  581.25
# Enchanter        7.0  512.382857  34.705633  480.0  485.84  500.00  530.00
# Juggernaut      14.0  588.617143  15.554685  561.2  580.56  584.74  594.58
# Marksman        21.0  538.523810  29.549313  481.0  518.00  539.00  561.00
# Skirmisher       7.0  576.428571  34.341514  523.0  555.00  585.00  595.68
# ...

# %%
classes='object'
attributes=LoL.select_dtypes(include=classes)

# %%
print(LoL['primary_attrs'].value_counts(normalize=True))
attributes
# Out:
# Marksman      0.141892
# Diver         0.108108
# Assassin      0.101351
# Burst         0.094595
# Specialist    0.094595
# Juggernaut    0.094595
# Vanguard      0.087838
# Battlemage    0.074324
# Enchanter     0.047297
# Catcher       0.047297
# Skirmisher    0.047297
# Warden        0.033784
# Artillery     0.027027
# Name: primary_attrs, dtype: float64
#     primary_attrs second_attrs third_attrs
# 0      Juggernaut     Manaless       Melee
# 1           Burst         Mana      Ranged
# 2        Assassin       Energy       Melee
# 3        Vanguard         Mana       Melee
# 4        Vanguard         Mana       Melee
# ..            ...          ...         ...
# 143      Assassin       Energy       Melee
# 144     Artillery         Mana      Ranged
# 145    Specialist         Mana      Ranged
# 146         Burst         Mana      Ranged
# 147       Catcher         Mana      Ranged
#
# [148 rows x 3 columns]

# %%
grid_index = [[j, r] for j in range(2) for r in range(2)]
fig, ax = plt.subplots(ncols = 2, nrows = 2, figsize=[30,20])
for i, d in enumerate(attributes.sort_values(by='primary_attrs')):
    sns.countplot(x = d, data= attributes.sort_values(by='primary_attrs'), ax=ax[tuple(grid_index[i])])

# %%
LoL
# Out:
#      health  health_per_lvl  health_regen  health_regen_per_lvl      ad  \
# 0    580.00            90.0           3.0                  1.00  60.000
# 1    526.00            92.0           6.5                  0.60  53.040
# 2    575.00            95.0           8.0                  0.50  62.400
# 3    600.00           106.0           8.5                  0.85  62.000
# 4    613.12            84.0           9.0                  0.85  53.380
# ..      ...             ...           ...                   ...     ...
# 143  584.00            85.0           7.0                  0.65  63.000
# 144  536.00            92.0           6.5                  0.60  54.208
# 145  504.00            82.0           5.5                  0.50  51.640
# 146  560.00            92.0           6.5                  0.60  58.000
# 147  504.00            79.0           5.5                  0.50  53.376
#
#      ad_per_lvl   armor  armor_per_lvl    mr  mr_per_lvl  attack_speed     ms  \
# ...
